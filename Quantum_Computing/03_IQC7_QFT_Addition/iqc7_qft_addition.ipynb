# %% [markdown]
# # IQC-7 QFT Addition
#
# Run the implementation below. The script saves the numerical results and figures in this folder.

# %%
from iqc7_qft_addition import main
results = main()

# %%
import json
print(json.dumps(results['metadata'], indent=2))

# %% [markdown]
# ## Generated figures

# %%
from IPython.display import Image, display
display(Image(filename='figures/teleportation_ideal_vs_noisy.png'))
display(Image(filename='figures/qft_addition_results.png'))
display(Image(filename='figures/qft_adder_circuit.png'))
