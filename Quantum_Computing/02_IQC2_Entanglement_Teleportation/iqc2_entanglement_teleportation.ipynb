# %% [markdown]
# # IQC-2 Entanglement and Teleportation
#
# Run the implementation below. The script saves the numerical results and figures in this folder.

# %%
from iqc2_entanglement_teleportation import main
results = main()

# %%
import json
print(json.dumps(results['metadata'], indent=2))

# %% [markdown]
# ## Generated figures

# %%
from IPython.display import Image, display
display(Image(filename='figures/bell_measurements.png'))
display(Image(filename='figures/teleportation_measurements.png'))
display(Image(filename='figures/teleportation_dynamic_circuit.png'))
