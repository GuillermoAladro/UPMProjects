# %% [markdown]
# # IQC-1 Quantum Fundamentals
#
# Run the implementation below. The script saves the numerical results and figures in this folder.

# %%
from iqc1_quantum_fundamentals import main
results = main()

# %%
import json
print(json.dumps(results['metadata'], indent=2))

# %% [markdown]
# ## Generated figures

# %%
from IPython.display import Image, display
display(Image(filename='figures/one_qubit_probabilities.png'))
display(Image(filename='figures/bell_state_probabilities.png'))
display(Image(filename='figures/no_cloning_circuit.png'))
